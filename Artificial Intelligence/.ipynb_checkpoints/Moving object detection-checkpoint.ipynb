# %%
import cv2
import imutils
import time

# %%
Frame = None
area = 500

# %%
cam = cv2.VideoCapture(0)
time.sleep(1)

# %%
while True :
    img = cam.read()[1]
    message = "Everything is ok!"
    grayImg = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gaussImg = cv2.GaussianBlur(grayImg,(21,21),0)
    if Frame is None :
        Frame = gaussImg
        continue
    imgdiff = cv2.absdiff(Frame,gaussImg)
    threshImg = cv2.threshold(imgdiff,100,255,cv2.THRESH_BINARY)[1]
    threshImg = cv2.dilate(threshImg,None,iterations = 2)
    cnts = cv2.findContours(threshImg.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    for c in cnts :
        if(cv2.contourArea(c) < area) :
            continue
        (x,y,width,height) = cv2.boundingRect(c)
        cv2.rectangle(img,(x,y),(x+width,y+height),(0,255,0),2)
        message = "Moving object detected"
        print(message)
    cv2.putText(img,message,(10,20),cv2.FONT_HERSHEY_TRIPLEX,0.5,(0,0,255),2)
    cv2.imshow("Camera Feed",img)
    key = cv2.waitKey(1) & 0xFF
    if(key == ord("e")) :
        break;
cam.release()
cv2.destroyAllWindows
# Out:
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# Moving object detected
# ...
